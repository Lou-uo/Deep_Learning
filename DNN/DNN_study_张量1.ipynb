# %%
#   1.3 用GPU存储张量
import torch

# 默认的张量存储在CPU上
ts1 = torch.randn(3,4)
print(ts1)

# # 移动到GPU上
# ts2 = ts1.to('cuda:0')
# print(ts2)
# Out:
# tensor([[ 0.4089, -0.0271, -0.0431, -0.8640],
#         [ 1.7661, -0.8924, -0.0301, -1.2766],
#         [ 1.0418,  1.0094,  0.2604, -2.2563]])
